# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
# numpy 常用於數值/陣列運算, pandas 擅長資料格式的調整, matplotlib 擅長繪圖
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE=sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
# np.linspace(0, 100, 101)是指 0~100 劃分成 101 個刻度(含頭尾), 所也就是 0, 1, 2,...,100 這 101 個數
x_lin = np.linspace(0, 100, 101)
# np.random.randn(101) 表示取樣了101次, 型態是 Array, 所以其他 + 與 * 的部分都是 Array 的加與乘, 一行就計算了101筆資料
y = (x_lin + np.random.randn(101) * 5) * w + b

# b. : b 就是 blue, 點(.) 就是最小單位的形狀
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 190.591
# The Mean absolute error is 11.234

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 我找的competitions:https://www.kaggle.com/c/word2vec-nlp-tutorial/overview/part-1-for-beginners-bag-of-words ，
# 他的dataset是用IMDB movie review，其中25000為training set，另外25000為testing set
#
# 1. 你選的這組資料為何重要
#
# answer:在看一些nn的論文，他們做的實驗都會用到這份資料集，我覺得這份資料集能夠幫助我們要做實驗的時候，很方便的取用。讓我們去訓練出一個更好的情緒分析的一個model，去判斷一段文字他是positive還是negative。或是，在商業用途上，若能夠運用情緒分析去了解公司的產品在市場上的評價是正向還是負向，那麼就行銷人員就能去作出對策。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# answer:IMDb 網路資料庫 (Internet Movie Database), 是一個電影相關的線上資料庫. IMDb 開始於 1990 年, 自 1998 年起成為亞馬遜旗下的網站, 至今已經累積大量的電影資訊. IMDb 共收錄了四百多萬作品資料.
#
# 3. 蒐集而來的資料型態為何
#
# answer:屬於非結構化的資料，需要思考資料轉換與標準化⽅方式。不過他有分labeled data跟unlabeled data，labeled data有把每段電影評論標為pos(1)或neg(0)
#
# 4. 這組資料想解決的問題如何評估
#     因為是要去評估電影評論是pos還是neg，所以是屬於二分類的問題，多使用正確率(accuracy)來評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# answer:我們假設現在車隊在網路上的評價不好，我們要想辦法提升我們車隊的服務品質，增加顧客回流率，並且在網路上留下好的口碑，增加客群，提升業績。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# answer:在提供載客服務時，就會要求顧客留下資料，並且可以讓顧客留下評價以及建議(如果願意提供建議或評價，可以給予下次服務的優惠)，再來也可以去爬網路上對於車隊的評價(像是社群媒體上的討論)，有了這些資料，就能夠分析出車隊需要去改進的地方，也可以知道網路上現在對於車隊的評價是好的還是壞的。
#
# 3. 蒐集而來的資料型態為何
#
# answer:蒐集來的資料屬於非結構化的資料，需要思考資料轉換與標準化⽅方式。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# answer:因為是要去評估網路上對於車隊的評論是pos還是neg，所以是屬於二分類的問題，多使用正確率(accuracy)來評估
